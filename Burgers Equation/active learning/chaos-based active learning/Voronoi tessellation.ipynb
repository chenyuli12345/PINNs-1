# %%
#Voronoi方法：先根据PINN的区域生成指定数目的Voronoi种子；然后在该区域内生成配位点；然后使用最近邻搜索算法，找到每个配位点的最近种子点，从而确定每个配位点的区域；
# Out:
# 2.2.1+cu121
# 3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]

# %%
#下面这行代码，是为了把自己编写的代码文件当作一共模块导入，这里是把Utilities文件夹中的plotting.py文件当作python的模块导入，对应的是下面的from plotting import newfig, savefig。路径要随着不同设备的系统做相应的修改
import sys #导入sys模块。sys模块提供了一些变量和函数，用于与 Python解释器进行交互和访问。例如，sys.path 是一个 Python 在导入模块时会查找的路径列表，sys.argv 是一个包含命令行参数的列表，sys.exit() 函数可以用于退出 Python 程序。导入 sys 模块后，你就可以在你的程序中使用这些变量和函数了。
sys.path.insert(0, '../../../Utilities/') #在 Python的sys.path列表中插入一个新的路径。sys.path是一个 Python 在导入模块时会查找的路径列表。新的路径'../../Utilities/'相对于当前脚本的路径。当你尝试导入一个模块时，Python 会在 sys.path 列表中的路径下查找这个模块。通过在列表开始位置插入一个路径，你可以让 Python 优先在这个路径下查找模块。这在你需要导入自定义模块或者不在 Python 标准库中的模块时非常有用。

import torch
#collections是python一个内置模块，提供了一些有用的数据结构
from collections import OrderedDict  #这个类是字典dict的一个子类，用于创建有序的字典。普通字典中元素顺序是无序的，在OrderedDict中元素的顺序是有序的，元素的顺序是按照它们被添加到字典中的顺序决定的。

from pyDOE import lhs #`pyDOE`是一个Python库，用于设计实验。它提供了一些函数来生成各种设计，如因子设计、拉丁超立方设计等。`lhs`是库中的一个函数，全名为"Latin Hypercube Sampling"，拉丁超立方采样。这是一种统计方法，用于生成一个近似均匀分布的多维样本点集。它在参数空间中生成一个非常均匀的样本，这对于高维数值优化问题非常有用，因为它可以更好地覆盖参数空间。
import numpy as np
import matplotlib.pyplot as plt
import scipy.io #导入了scipy库中的io模块。scipy.io模块包含了一些用于文件输入/输出的函数，例如读取和写入.mat文件（MATLAB格式）
from scipy.interpolate import griddata #`scipy.interpolate`是`scipy`库中的一个模块，提供了许多插值工具，用于在给定的离散数据点之间进行插值和拟合。`griddata`是这个模块中的一个函数，用于在无规则的数据点上进行插值。

import random

import skopt #用于优化问题的库，特别是机器学习中的超参数优化
from distutils.version import LooseVersion #distutils是Python的一个标准库，用于构建和安装Python包。LooseVersion是一个类，用于比较版本号


from plotting_torch import newfig, savefig #从自定义的plotting_torch.py文件中导入了newfig和savefig函数。这两个函数用于创建和保存图形。这两个函数的定义在plotting_torch.py文件中

from mpl_toolkits.axes_grid1 import make_axes_locatable #`mpl_toolkits.axes_grid1`是`matplotlib`库的一个模块，提供了一些高级的工具来控制matplotlib图形中的坐标轴和颜色条。`make_axes_locatable`是模块中的一个函数，用于创建一个可分割的坐标轴。可以在这个坐标轴的四个方向（上、下、左、右）添加新的坐标轴或颜色条。
import matplotlib.gridspec as gridspec #是`matplotlib`库的一个模块，用于创建一个网格布局来放置子图。在`matplotlib`中可以创建一个或多个子图（subplot），每个子图都有自己的坐标轴，并可以在其中绘制图形。`gridspec`模块提供了一个灵活的方式来创建和放置子图。
import time #一个内置模块，用于处理时间相关的操作。


from tqdm import tqdm #一个快速，可扩展的python进度条库，可以在python长循环中添加一个进度提示信息，用户只需要封装任意的迭代器tqdm(iterator)。



from scipy.spatial import Voronoi, voronoi_plot_2d 
#scipy.spatial提供了空间数据结构和算法的功能。主要用于处理和分析多维空间中的数据。包括了一系列用于计算多维空间中点集的函数和类，例如距离计算、空间关系、空间结构和形状分析等
#Voronoi是一个用于生成Voronoi图的类。Voronoi图是一种将平面分割成多个区域的方法，每个区域由一组特定的点定义，这些点距离区域内的任何位置都比距离区域外的其他点更近。
#voronoi_plot_2d是一个用于绘制二维Voronoi图的函数。它接受一个Voronoi对象作为输入，并生成该Voronoi图的可视化表示

# %%
#1.根据PINN的区域生成指定数目的Voronoi种子

# 生成一个Voronoi-Poisson划分，这意味着它生成一个Poisson点过程，然后使用它生成一个相应的Voronoi细分。Voronoi细分也称为Dirichlet细分或Voronoi图。

# 在矩形上创建一个（均匀）Poisson点过程（PPP，Poisson point process），然后使用SciPy函数Voronoi找到Voronoi镶嵌，该函数基于Qhull项目[2]。
# PPP的所有点和Voronoi单元都是任意编号的。

# [1] http://scipy.github.io/devdocs/generated/scipy.spatial.Voronoi.html
# [2] http://www.qhull.org/

plt.close('all')  #关闭所有之前的图形界面，确保从一个干净的状态开始绘图

#定义模拟窗口的边界
xMin = 0
xMax = 1
yMin = -1
yMax = 1

xDelta = xMax - xMin #区域宽度
yDelta = yMax - yMin #区域高度
areaTotal = xDelta * yDelta #区域面积

# PPP的强度，即单位面积内点的平均密度
lambda0 = 20

# 模拟泊松点过程（PPP）
numbPoints = np.random.poisson(lambda0 * areaTotal)  # 泊松点（种子）数量，点数量为随机数生成，随机数是泊松分布，期望值和方差为区域面积乘以PPP强度（密度）
xx = xDelta * np.random.uniform(0, 1, numbPoints) + xMin  # 泊松点的x坐标，具体为一个随机数×区域宽度加上区域最小x坐标，即在模拟区域内按均匀分布随机采样numbPoints个点
yy = yDelta * np.random.uniform(0, 1, numbPoints) + yMin  # 泊松点的y坐标，具体为一个随机数×区域高度加上区域最小y坐标，即在模拟区域内按均匀分布随机采样numbPoints个点

seed=np.stack((xx,yy), axis=1) #将x和y坐标合并成一个数组，即种子的坐标，形状为(n,2)，n为点的数量


#使用内置函数执行Voronoi图生成

voronoiData=Voronoi(seed) #使用Voronoi函数进行Voronoi划分，得到Voronoi图的数据
#Voronoi函数的输入是一个点集(也就是每个单位的种子，二维的话为(n,2)形状)，输出是一个Voronoi对象，包含了Voronoi图的所有信息，包括顶点、边和单元等
vertexAll=voronoiData.vertices #从数据中提取所有Voronoi顶点
cellAll=voronoiData.regions #从数据中提取所有Voronoi单元，一些单元可能为空

#绘制Voronoi图和PPP
#使用内嵌函数绘制Voronoi图，其中show_points和show_vertices参数控制是否显示生成点（即seed/Voronoi的输入点/数据）和顶点（Voronoi各个单元的交点）
voronoi_plot_2d(voronoiData, show_points=True,show_vertices=False)


#给每个点添加编号
for ii in range(numbPoints):
    plt.text(xx[ii]+xDelta/50, yy[ii]+yDelta/50, ii) #在图标的某个位置上添加文本，文本内容为点的编号，位置为点的坐标加上区域宽度和高度的1/50（为了做微调）

# %%
#定义采样函数，目的是采用sampler方法，生成n_samples个在指定空间内的准随机样本，这里space为二维的，因此每个样本都是一个二维点，即n_samples*2的数据点

#共有6种采样器，分别是LHS、Halton、Hammersley、Sobol、Grid和Random，均为均匀采样方法

def caiyang(n_samples, sampler): #接受两个参数，n_samples是样本数量，sampler是采样器名称，是一个字符串
    space = [(-1.0, 1.0), (0.0, 1.0)] #指定样本生成的空间，一个二维空间，第一个维度是-1到1，第二个维度是0到1

    #根据sampler的不同，选择不同的采样器，返回的sampler是一个采样器对象
    if sampler == "LHS": #如果采样器是LHS（拉丁超采样，每个维度都被均匀划分为等量区间，每个样本都是从每个维度的一个区间中随机选取的）
        sampler = skopt.sampler.Lhs(lhs_type="centered", criterion="maximin", iterations=1000) #第一个参数表示如何从每个区间选取样本，这里表示从每个区间的中心选取样本；第二个参数表示如何划分区间，这里表示尽可能使样本之间的最小距离最大；第三个表示通过优化过程得到样本量的迭代次数（即会尝试1000种不同的样本配置，并最终选择质量最好的那个）
    elif sampler == "Halton": #Halton序列是一种低差异序列，用于在高维空间中生成点
        sampler = skopt.sampler.Halton(min_skip=-1, max_skip=-1)  #两个参数用于控制序列的起始点，Halton序列可以通过跳过序列的前几个点来改变序列的七十点。两个参数分别制定了跳过点的最小和最大数量，这里-1表示不跳过任何点
    elif sampler == "Hammersley": #Hammersley序列是一种低差异序列，用于在高维空间中生成点
        sampler = skopt.sampler.Hammersly(min_skip=-1, max_skip=-1) #两个参数用于控制序列的起始点，Hammersley序列可以通过跳过序列的前几个点来改变序列的七十点。两个参数分别制定了跳过点的最小和最大数量，这里-1表示不跳过任何点
    elif sampler == "Sobol":
        # Remove the first point [0, 0, ...] and the second point [0.5, 0.5, ...], which are too special and may cause some error.
        # Sobol采样器的实现有一个问题，即生成的前两个样本点通常不是随机的而是固定的，Sobol序列的前两个点（[0, 0, ...]和[0.5, 0.5, ...]）在许多情况下都被认为是“特殊”的点，可能会对某些计算产生不利影响。因此设置跳过前两个点，而且skopt库在0.9版本号取消了max/min_skip参数，所以需要根据skopt的版本号来选择不同的参数
        if LooseVersion(skopt.__version__) < LooseVersion("0.9"): #先检查skopt的版本是否大于0.9,若小于
            sampler = skopt.sampler.Sobol(min_skip=2, max_skip=2, randomize=False) #则使用Sobol采样器，min_skip和max_skip表示跳过的点的数量，这里表示跳过前两个点，randomize表示是否随机化
        else: #若skopt的版本大于0.9
            sampler = skopt.sampler.Sobol(skip=0, randomize=False) #则使用Sobol采样器，skip表示跳过的点的数量，这里表示不跳过任何点，randomize表示是否随机化 
            return np.array(sampler.generate(space, n_samples + 2)[2:]) #生成n_samples+2个样本，然后返回除了前两个样本之外的所有样本，也就是返回n_samples个样本，每个样本都是一个二维点，且范围在指定的空间space里面
    elif sampler == "Grid":
        x_min, x_max = space[1]
        t_min, t_max = space[0]
        
        # 计算每个维度的网格大小
        x_grid_size = (x_max - x_min) / (n_samples // int(np.sqrt(n_samples)) - 1) # x维度上（纵轴），每行有10个点
        t_grid_size = (t_max - t_min) / int(np.sqrt(n_samples))  # 
        
        # 生成等距均匀网格采样点
        samples = []
        for i in range(n_samples // int(np.sqrt(n_samples))):
            for j in range(int(np.sqrt(n_samples))):
                # 计算每个网格单元的中心点
                x = x_min + i * x_grid_size
                t = t_min + j * t_grid_size
                samples.append([t, x])
        
        return np.array(samples)
    
    elif sampler == "Random":
        # 从space中提取出x_min, x_max, t_min, t_max
        x_min, x_max = space[1]
        t_min, t_max = space[0]

        # 生成x和t的随机数
        x = np.random.rand(n_samples, 1) * (x_max - x_min) + x_min
        t = np.random.rand(n_samples, 1) * (t_max - t_min) + t_min

        # 将x和t合并为一个(n_samples, 2)的数组
        samples = np.hstack((t, x))
        return samples #生成一个形状为(n_samples, 2)的随机数组



    return np.array(sampler.generate(space, n_samples)) #生成n_samples个样本，每个样本都是一个二维点，且范围在指定的空间space里面（n_samples*2）

# %%
#2.生成配位点，X_f_train第一列表示x，第二列表示t
X_f_train = caiyang(1000, "LHS")

# %%
#绘制PINN热图和配位点的分布情况

data = scipy.io.loadmat('../../data/burgers_shock.mat')
#从data字典中取出变量tt和x的值，并转换为一维数组（flatten方法），最后tongg[:,None]将一维数组转换为二维数组
t = data['t'].flatten()[:,None]
x = data['x'].flatten()[:,None]
Exact = np.real(data['usol']).T #从data数据中取出usol的值，并取实部，最后转置，赋值给Exact
#生成一个二位网络，X和T是输出的二维数组
#这个点结果是X和T均为形状为[len(t),len(x)]的二维数组，X的每一行都是x，一共len(t)行，T的每一列都是t，一共len(x)列
X, T = np.meshgrid(x,t)

X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))  #按列堆叠数组，X_star是一个二维数组，其中第一列是X的展平，第二列是T的展平
u_star = Exact.flatten()[:,None]    #对Exact_u使用flatten方法将其转换为一维数组，最后使用[:,None]将其转换为二维数组   


#使用griddata函数将X_star、u_pred插值到网格上，得到U_pred
U_star = griddata(X_star, u_star.flatten(), (X, T), method='cubic')


###### Row 0: u(t,x) ##################    

fig = plt.figure(figsize=(9, 5)) #这里figure是一个figure对象，是一个图形窗口，代表整个图形，设置图形大小为宽9英寸高5 英寸
ax = fig.add_subplot(111) #在图形的1*1网格的第一个位置添加一个子图

#绘图的数据来源
h = ax.imshow(U_star.T, interpolation='nearest', cmap='rainbow', 
              extent=[t.min(), t.max(), x.min(), x.max()], 
              origin='lower', aspect='auto')   #imshow函数用于显示图像，接受一些参数，第一个参数是图像数据，这里是U_pred的转置；第二个参数是插值方法（用于在像素之间插入新的像素），这里是最邻近插值；
                                                   #第三个参数是颜色映射，这里是用彩虹色图；第四个参数是图像的范围；第五个参数是图像的原点位置，这里表示原点在右下角；第六个参数是图像的纵横比，这里表示调整横纵比以填充整个axes对象
                                                   #最后的结果返回一个axesimage对象，也就是h，可以通过这个对象进一步设置图像的属性


#添加颜色条
divider = make_axes_locatable(ax)  #使用 make_axes_locatable 函数创建了一个 AxesDivider 对象。这个函数接受一个 Axes 对象作为参数，返回一个 AxesDivider 对象。AxesDivider 对象可以用来管理子图的布局，特别是当你需要在一个图的旁边添加另一个图时。
cax = divider.append_axes("right", size="5%", pad=0.10) #使用append_axes方法在原始轴的右侧添加了一个新的轴。append_axes 方法接受三个参数：位置（"right"）、大小（"5%"）和间距（0.10）。在原始轴的右侧添加了一个新的轴，新轴的大小是原始轴的 5%，新轴与原始轴之间的间距是 0.05 英寸
   
cbar = fig.colorbar(h, cax=cax)#使用colorbar方法在新轴上添加了一个颜色条。colorbar 方法接受两个参数：axesimage 对象（h）和新轴（cax）。并记这个颜色条的名字是cbar
cbar.ax.tick_params(labelsize=15) #设置颜色条刻度标签大小，这里bar是之前定义的


#在图上绘制散点图
ax.plot(
    X_f_train[:,1], 
    X_f_train[:,0], 
    'kx', label = 'Data (%d points)' % (X_f_train.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
) #在ax上绘制散点图，前两个参数是散点的x坐标和y坐标；kx表示黑色的x（散点形状是x），label是散点的标签，clip_on表示散点可以绘制在轴的边界外
  #新加了一个alpha=1.0用来设置标记的透明度，1.0表示完全不透明  




#设置图的标签、图例、标题和刻度标签
#设置ax子图的x轴的标签为t，y轴的标签为x。这里$t$和$x$是latex格式的文本，用于生成数学公式
ax.set_xlabel('$t$', size=20)
ax.set_ylabel('$x$', size=20)
#设置子图ax的图例，第一个参数用来设置图例的位置，这里表示图例放在上方中央;第二个参数用来设置图例的锚点，接受一个元组，表示x和y坐标，表示把图例的锚点设置在x坐标为0.9，y坐标为-0.05处;frameon=False表示不显示图例的边框;第三个参数设置图例的列数，分为5列；最后一个参数设置图例属性，接受字典，这里表示设置图例字体大小为15；最后返回的leg是一个legend对象，表示图形的图例
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.9, -0.05), 
    ncol=5, 
    frameon=False, 
    prop={'size': 15}
)
#设置子图ax的标题为$u(t,x)$，表示latex格式的文本，用于生成数学公式，fontsize=10表示字体大小为20
ax.set_title('$u(t,x)$', fontsize = 20) # font size doubled，两倍化子图标题
ax.tick_params(labelsize=15)#用来设置刻度标签的大小。`tick_params`是`Axes`对象的一个方法，可以用来设置刻度线的属性。在这里，`labelsize=15` 是用来设置刻度标签的字体大小的。


#显示图片
plt.show() #显示所有打开的图形的函数

# %%
#互换配位点的第一列和第二列，为了和seed的坐标匹配，互换后X_f_train变为X_f_swapped，第一列表示t，第二列表示x
print(seed)
print(X_f_train)
# 互换第一列和第二列
# 先复制原始数据
X_f_swapped = np.copy(X_f_train)

# 在复制的数组上互换第一列和第二列
X_f_swapped[:, [0, 1]] = X_f_swapped[:, [1, 0]]

print(X_f_swapped)
# Out:
# [[ 0.95059738  0.24161862]
#  [ 0.80051561  0.69960167]
#  [ 0.41760764  0.48538619]
#  [ 0.35624278 -0.42002001]
#  [ 0.78566381 -0.78711413]
#  [ 0.88354249  0.56708097]
#  [ 0.46730774 -0.79506227]
#  [ 0.98120338  0.73840107]
#  [ 0.61089477  0.61131753]
#  [ 0.90668861  0.97435413]
#  [ 0.95516895 -0.53949789]
#  [ 0.46087548  0.93457543]
#  [ 0.2413161  -0.6820683 ]
#  [ 0.81146864 -0.99016983]
#  [ 0.67053276 -0.8878207 ]
#  [ 0.94382906 -0.34813884]
#  [ 0.44968092  0.60645848]
#  [ 0.18280204  0.07224477]
#  [ 0.94277527 -0.58304809]
#  [ 0.54332928 -0.2790227 ]
#  [ 0.38894107 -0.51077077]
#  [ 0.5662756   0.15426978]
#  [ 0.47855176  0.08406659]
#  [ 0.40022392  0.74348447]
#  [ 0.97093271 -0.28576481]
#  [ 0.01337043 -0.16777103]
#  [ 0.32335712  0.84142614]
#  [ 0.61592881 -0.52988114]
#  [ 0.91730766 -0.36469626]
#  [ 0.99518578  0.42658318]
#  [ 0.18678509 -0.14422532]
#  [ 0.57503061  0.52400905]
#  [ 0.27394089 -0.00693449]
#  [ 0.36818905  0.37872631]
#  [ 0.30546052 -0.47357603]
#  [ 0.97314729 -0.9994783 ]
#  [ 0.89367688 -0.30185407]
#  [ 0.6748304  -0.92046902]
#  [ 0.84129894  0.96838637]
#  [ 0.64435285  0.11995486]
#  [ 0.10995127  0.99860775]
#  [ 0.77684821  0.00907629]
#  [ 0.58726579  0.11543257]
#  [ 0.31300679  0.16353886]]
# [[ 0.241   0.1375]
#  [ 0.063   0.2835]
#  [-0.153   0.6345]
#  ...
#  [ 0.925   0.6135]
#  [-0.085   0.0375]
#  [ 0.571   0.0515]]
# [[ 0.1375  0.241 ]
#  [ 0.2835  0.063 ]
#  [ 0.6345 -0.153 ]
#  ...
#  [ 0.6135  0.925 ]
#  [ 0.0375 -0.085 ]
#  [ 0.0515  0.571 ]]

# %%
#3.使用最近邻搜索算法，找到每个配位点的最近种子点

from scipy.spatial import cKDTree #用于创建k维空间中的k-d树（k-dimensional tree）。k-d树是一种数据结构，用于组织和查询在k维度空间中的点


# 创建 cKDTree 实例，seed形状是(n,k=2)，n是种子点的数量，k为空间维度，该函数将种子点组织到一个k-d树中，以便快速查询最近邻点。可以使用tree上的方法执行各种空间查询
tree = cKDTree(seed)

# 对每个点进行最邻近搜索
distances, indices = tree.query(X_f_swapped) #用于执行查询操作，对于X_f_swapped中的每个点，查找并返回tree上最近的种子点的距离和索引

# indices 数组中的每个元素都是对应点最近的种子点的索引，可以使用这个索引作为标签

# 打印每个点的最近种子点索引
for i, index in enumerate(indices):
    print(f"点 {X_f_swapped[i]} 最近的种子点是 {seed[index]}，索引（标签）为 {index}")
# Out:
# 点 [0.1375 0.241 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.2835 0.063 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [ 0.6345 -0.153 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.7185 0.187 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.7455 0.123 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.3285 -0.829 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.2225 0.657 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.3975 0.267 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.0675 0.753 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.3005 -0.727 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.0865 -0.209 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.3795 -0.397 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [0.1695 0.981 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.2385 -0.261 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.7915 -0.421 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [ 0.5295 -0.083 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.0895 -0.201 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.8365 -0.445 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [ 0.1475 -0.985 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.2535 0.841 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.5705 -0.919 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.4125 -0.697 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.2695 -0.151 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.1815 -0.267 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.0905 0.479 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.6295 0.027 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.5065 0.835 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.1855 -0.901 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.4345 0.559 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.9905 0.593 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.5195 -0.051 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.9255 0.337 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.6755 0.609 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.2765 0.143 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.4235 0.001 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.9825 0.749 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.3365 0.751 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.8855 -0.961 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [0.1305 0.665 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.3885 -0.487 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.9185 -0.431 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [ 0.6785 -0.375 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.0005 0.349 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.5355 0.539 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.4865 0.259 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [ 0.4855 -0.741 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.0435 -0.887 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.7055 -0.507 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.5645 -0.915 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [ 0.4795 -0.203 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.5845 0.711 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.0845 0.013 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.5315 -0.849 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.4415 -0.753 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.6605 -0.419 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.6745 -0.745 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.0315 0.781 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.4885 -0.783 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.8405 -0.971 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [ 0.5495 -0.483 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.3595 0.949 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.3715 -0.251 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [0.4815 0.357 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.0875 -0.563 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.1235 -0.813 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.4485 -0.211 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.7075 -0.639 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.3805 -0.559 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.1015 -0.297 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.6575 0.761 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [0.4225 0.319 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.6565 0.375 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.6415 -0.993 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [0.2875 0.167 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.0035 0.481 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.2715 -0.475 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.8065 -0.161 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.1325 0.317 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.9235 -0.269 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.7985 -0.027 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.1075 -0.317 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.5975 -0.979 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [0.7615 0.139 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.7955 0.243 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.6185 0.431 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.6035 0.019 ] 最近的种子点是 [0.58726579 0.11543257]，索引（标签）为 42
# 点 [0.2035 0.471 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.2435 -0.149 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.2565 -0.593 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.1345 0.783 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.0245 -0.521 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.9655 -0.429 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [ 0.7825 -0.805 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.3215 0.433 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.2305 0.275 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.2555 -0.089 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [ 0.9605 -0.289 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [0.0395 0.895 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.1975 -0.779 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.8115 0.051 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.1055 -0.823 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9025 0.213 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.9245 0.803 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.0555 0.745 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.0015 0.049 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.4195 -0.219 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.2445 0.423 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.0965 -0.343 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.2575 0.627 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.3175 0.133 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.9665 0.739 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [ 0.9075 -0.945 ] 最近的种子点是 [ 0.97314729 -0.9994783 ]，索引（标签）为 35
# 点 [ 0.0885 -0.019 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.6055 -0.357 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.7105 -0.111 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.7805 -0.063 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.7555 0.887 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.0485 0.597 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.3615 0.853 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.2745 -0.497 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.6585 -0.917 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.1995 -0.307 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.4155 -0.825 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.2005 0.727 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.8205 0.289 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.4095 -0.413 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.3165 -0.517 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.0165 0.235 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.0385 -0.327 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.2395 -0.277 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.5595 0.257 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [0.9095 0.955 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [0.5575 0.551 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.1435 0.223 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.4945 -0.935 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.6935 0.967 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.6365 0.691 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.7245 -0.331 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.7305 -0.447 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.2655 0.635 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.5435 0.671 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.0615 -0.603 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.0835 -0.571 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.2685 -0.131 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.8615 -0.075 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.0945 -0.109 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.0065 -0.775 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.7665 -0.865 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.9295 -0.481 ] 最近的种子点是 [ 0.95516895 -0.53949789]，索引（标签）为 10
# 点 [ 0.2285 -0.217 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.6005 0.221 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [0.7375 0.725 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.2345 -0.819 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.8585 0.305 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.4115 0.447 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.5205 0.607 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.8945 0.951 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [ 0.1145 -0.591 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.2955 0.965 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.0185 -0.581 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.4305 0.833 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.7325 -0.115 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.6305 0.599 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.2945 -0.163 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.8415 0.161 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.3935 -0.193 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.2275 0.633 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.4705 -0.835 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.4645 -0.489 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.7015 -0.299 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.0525 -0.409 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.8775 -0.853 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.1025 0.569 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.6475 -0.417 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.8725 -0.619 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [ 0.3335 -0.287 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.4635 -0.551 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [0.8305 0.817 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [0.0095 0.329 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.5335 0.009 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.0475 -0.015 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.2605 0.303 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.9635 0.703 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [ 0.9515 -0.827 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.9215 0.653 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.9205 0.111 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.4535 0.325 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.3495 -0.841 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.8025 -0.181 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.5795 0.237 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [ 0.3115 -0.575 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [0.2485 0.575 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.8375 0.331 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.5515 0.003 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.1705 -0.381 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.3965 -0.293 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [0.7495 0.029 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.8395 -0.977 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [ 0.9325 -0.437 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [0.6555 0.611 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.0735 0.721 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.8285 0.169 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.6195 -0.929 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.0495 -0.359 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.0715 -0.623 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.8165 -0.025 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.6465 -0.427 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.7675 0.089 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.0365 0.039 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.6665 -0.771 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [0.0655 0.793 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.7635 0.765 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.6145 -0.963 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.2665 -0.473 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.5855 -0.523 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.8185 0.511 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.3855 0.125 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.6405 -0.613 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.9355 0.413 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [0.8665 0.921 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [ 0.1205 -0.183 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.7765 0.285 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.3425 -0.467 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.4625 0.359 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.2055 -0.879 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9485 0.225 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.7285 0.277 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.8265 0.407 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [ 0.7995 -0.263 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.3955 0.655 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.8485 0.327 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.3385 0.621 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [ 0.5175 -0.763 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.1495 -0.199 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.8715 0.845 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.7155 0.457 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.7465 0.685 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.5525 -0.577 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.2405 0.067 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.3985 -0.035 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [ 0.7215 -0.553 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.2905 -0.423 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.9145 0.023 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.6205 0.037 ] 最近的种子点是 [0.58726579 0.11543257]，索引（标签）为 42
# 点 [0.0635 0.189 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.6285 0.095 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.8565 -0.951 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [ 0.2125 -0.039 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [0.4455 0.401 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.4765 0.477 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.1175 0.157 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.4995 0.821 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.0105 0.963 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.9165 -0.975 ] 最近的种子点是 [ 0.97314729 -0.9994783 ]，索引（标签）为 35
# 点 [ 0.8685 -0.247 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.1925 -0.543 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.7895 0.117 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.0915 0.913 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.6775 0.239 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.9365 -0.271 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [0.8055 0.713 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.4265 -0.097 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [0.1895 0.421 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.2045 0.799 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.8955 0.363 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [ 0.3875 -0.895 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.4745 0.141 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.8445 0.881 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [ 0.2525 -0.315 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.8755 -0.099 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.2165 0.805 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.7775 -0.177 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.7925 -0.873 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.7885 -0.615 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [ 0.6705 -0.605 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.1915 0.977 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.5215 -0.143 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.5585 -0.411 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.9315 -0.123 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [0.6675 0.339 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.6885 0.661 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.5695 -0.007 ] 最近的种子点是 [0.58726579 0.11543257]，索引（标签）为 42
# 点 [0.0275 0.131 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.5905 0.439 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.3135 0.105 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.9735 0.453 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [0.6335 0.769 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.0595 -0.259 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.0605 -0.831 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.8275 -0.821 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.7315 -0.811 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.0145 -0.295 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.7295 -0.105 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.2585 0.969 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.0575 -0.663 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.1185 -0.565 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.5985 -0.705 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.2245 0.831 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.8155 -0.279 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.3305 0.517 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.8845 0.741 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.0135 -0.725 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.3085 0.181 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.3745 -0.839 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.0305 0.863 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.0995 0.313 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.7425 -0.729 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.6795 0.763 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.3685 -0.631 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.3835 -0.071 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [0.6125 0.573 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.2805 0.335 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.0955 -0.329 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.8325 -0.645 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.8125 0.017 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.6975 0.053 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.8355 0.219 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.2365 -0.953 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.3125 -0.485 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.7795 0.007 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.7905 -0.385 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [0.0195 0.393 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.7005 0.883 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.3055 0.497 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.1135 -0.321 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.9895 -0.119 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [0.0695 0.199 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.2015 0.427 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.0795 -0.407 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.3435 0.197 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.4755 0.729 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.0725 0.961 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.5675 0.321 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [ 0.4875 -0.709 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.9915 0.579 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.1615 0.939 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.1555 -0.757 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.7535 -0.197 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.8765 -0.911 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [0.8705 0.059 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.2205 -0.439 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.5245 0.937 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.0345 -0.087 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.3905 0.877 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.9415 0.927 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [0.4035 0.441 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.5785 -0.515 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.8475 -0.237 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.9395 0.295 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.2845 0.851 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.5475 -0.519 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.4695 0.709 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.9675 0.367 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [ 0.8915 -0.529 ] 最近的种子点是 [ 0.95516895 -0.53949789]，索引（标签）为 10
# 点 [ 0.7655 -0.081 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.8045 0.261 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.3945 0.555 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.8735 -0.761 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.3515 -0.117 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [ 0.1425 -0.635 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.9135 -0.245 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.4975 0.911 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.1675 -0.127 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.4425 0.537 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.3545 -0.949 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.8105 -0.459 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [0.5085 0.849 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.3455 -0.659 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.1225 -0.555 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.8345 0.467 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.3405 -0.877 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.3625 -0.373 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.5235 -0.067 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.7695 -0.379 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.3775 0.865 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.6425 0.355 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.1635 0.215 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.1405 -0.673 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.8435 0.057 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.9015 -0.817 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.4615 -0.303 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.2725 -0.541 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.7725 0.021 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.6075 -0.611 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.4025 -0.129 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [ 0.3845 -0.957 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.7135 -0.657 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.5005 0.469 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.2785 -0.215 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.5045 -0.391 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.6515 0.459 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.3145 -0.339 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [0.9965 0.779 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [ 0.0785 -0.719 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.0505 -0.047 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.0025 0.403 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.4825 0.879 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.7385 0.449 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.4655 0.103 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.8875 0.521 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.1455 0.811 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.9085 -0.285 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.3505 -0.711 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9505 0.121 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.8235 0.773 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.1485 -0.159 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.3655 -0.501 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.4395 -0.179 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.6695 -0.001 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.6155 -0.479 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.3695 0.837 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.6995 0.233 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.1465 -0.967 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9155 0.659 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.5125 -0.947 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.8525 -0.661 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.1195 0.077 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.9275 -0.609 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.6835 0.567 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.4725 -0.765 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.3355 0.079 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.8675 -0.627 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [ 0.1745 -0.669 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.3665 0.819 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.0295 -0.525 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.2415 0.195 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.7705 0.809 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [0.2735 0.203 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.6445 -0.157 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.3265 -0.717 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9195 0.735 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.8425 0.211 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.2615 -0.907 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.4055 -0.539 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [0.9845 0.669 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [ 0.8895 -0.843 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.6965 -0.707 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.6715 -0.013 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.0565 -0.451 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.9805 -0.155 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [ 0.0755 -0.361 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.2645 0.301 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.4405 -0.583 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.5655 -0.335 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.6625 0.379 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.5305 0.985 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.6275 0.973 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.3225 0.493 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.3765 -0.309 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.1115 -0.909 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.5145 0.673 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.7945 0.107 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.3415 -0.273 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.4845 -0.243 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.3825 -0.731 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.9455 0.689 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.3645 0.875 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.6545 0.915 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [ 0.4575 -0.265 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.2505 0.343 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.2105 -0.545 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.3025 0.113 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.0115 -0.955 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9005 0.097 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.2935 0.699 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.9055 -0.433 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [ 0.6025 -0.807 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [0.1515 0.929 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.5625 -0.991 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [0.7605 0.265 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.4045 -0.633 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [0.9125 0.719 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.2925 0.263 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.5605 -0.053 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.2425 0.603 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.5635 0.683 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.6455 -0.195 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.1155 0.697 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.8605 0.629 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.6825 -0.495 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.1105 0.463 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.0325 -0.847 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.4185 -0.491 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.2215 -0.125 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.8965 0.651 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.2185 0.443 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.5755 0.531 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.7755 -0.903 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [ 0.0825 -0.037 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.8645 0.871 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.4915 0.135 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.7355 -0.503 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.3535 -0.781 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.3245 0.589 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [ 0.6165 -0.021 ] 最近的种子点是 [0.58726579 0.11543257]，索引（标签）为 42
# 点 [ 0.3475 -0.677 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.6245 -0.939 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [0.3635 0.687 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.0585 0.279 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.2855 -0.213 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.8195 -0.403 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [ 0.8225 -0.029 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.5865 0.631 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.7095 0.149 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.9645 0.065 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.2335 -0.107 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.0055 -0.225 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.4785 -0.235 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.9495 -0.997 ] 最近的种子点是 [ 0.97314729 -0.9994783 ]，索引（标签）为 35
# 点 [0.4585 0.857 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.9225 0.323 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.8545 0.127 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.5225 -0.461 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.3525 -0.141 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [0.7585 0.201 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.5135 0.759 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.5095 -0.735 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.1275 0.173 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.5055 0.291 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [ 0.5275 -0.229 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.1955 -0.061 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.3785 0.553 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.4735 -0.399 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.6905 -0.861 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [0.7205 0.353 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.5815 -0.311 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.4145 0.943 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.1765 0.485 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.8625 0.085 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.7365 0.813 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.1795 -0.069 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.2115 -0.231 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.4465 -0.597 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [0.7685 0.499 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.0465 -0.253 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.6635 0.071 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.5805 0.807 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.8815 -0.233 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.6535 -0.693 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.4015 -0.885 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.3465 -0.713 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.6765 0.137 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.4955 0.957 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.9285 0.991 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [ 0.6385 -0.133 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.8455 0.541 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.9535 -0.095 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [ 0.4295 -0.933 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.1445 -0.921 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.4675 -0.749 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.1035 -0.337 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.5415 -0.101 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.5265 -0.323 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.6595 0.909 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.5955 0.491 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.2235 -0.995 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.2795 -0.569 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.2865 -0.851 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.3605 -0.773 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.5505 -0.469 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.3915 -0.893 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.5565 -0.691 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.3255 -0.401 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.7065 -0.547 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.4255 0.619 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [ 0.7035 -0.845 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [ 0.7625 -0.549 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.8985 0.389 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [ 0.4775 -0.389 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.1845 -0.405 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.8175 -0.313 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.2475 0.823 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.9115 -0.465 ] 最近的种子点是 [ 0.95516895 -0.53949789]，索引（标签）为 10
# 点 [0.7445 0.043 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.5105 -0.683 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.5885 0.615 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.4335 -0.665 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.8515 -0.737 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.5445 0.547 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.7565 -0.325 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.4965 -0.801 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.1935 0.897 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.4105 -0.367 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.4985 -0.165 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.5325 -0.965 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.4065 -0.871 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.3395 -0.189 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.6525 -0.207 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.7225 0.309 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.8785 0.255 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.8385 0.269 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.1645 0.625 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.6505 0.995 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.1985 0.795 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.1245 -0.257 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.3585 0.583 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [ 0.2195 -0.931 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.3555 0.743 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.9405 0.935 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [0.9975 0.227 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.1005 0.041 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.6875 -0.799 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [ 0.0255 -0.537 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.6045 -0.103 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.1575 -0.913 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.6395 0.941 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.1965 0.705 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.9425 0.971 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [ 0.7575 -0.869 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.0985 -0.139 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.7845 0.209 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.3895 -0.579 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [0.3295 0.035 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [0.2915 0.369 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.0425 -0.671 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.4245 -0.625 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [0.3375 0.523 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.8145 -0.999 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [ 0.7505 -0.679 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.6255 -0.793 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [0.5555 0.361 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.4325 0.509 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.4215 0.153 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.1335 -0.221 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.1875 0.503 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.5665 0.945 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.7875 -0.809 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.7405 -0.241 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.6915 -0.275 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.3815 -0.205 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.9565 -0.347 ] 最近的种子点是 [ 0.94382906 -0.34813884]，索引（标签）为 15
# 点 [ 0.0205 -0.617 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.5115 0.419 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.9575 -0.715 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.8925 0.015 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.1065 -0.441 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.8075 -0.653 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.0335 0.061 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.8535 0.507 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.1545 -0.395 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.5465 -0.453 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.5935 0.385 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.9745 -0.889 ] 最近的种子点是 [ 0.97314729 -0.9994783 ]，索引（标签）为 35
# 点 [0.8015 0.365 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.5915 0.873 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.7255 0.387 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.7335 0.179 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.9835 -0.905 ] 最近的种子点是 [ 0.97314729 -0.9994783 ]，索引（标签）为 35
# 点 [ 0.4685 -0.167 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.5945 -0.797 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [0.6985 0.191 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.3235 -0.011 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [ 0.5545 -0.415 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.2495 -0.721 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.7815 0.307 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.1785 0.101 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.2625 0.395 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.7415 -0.093 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.8555 0.975 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.6175 0.031 ] 最近的种子点是 [0.58726579 0.11543257]，索引（标签）为 42
# 点 [ 0.1255 -0.655 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.8085 -0.345 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.4805 -0.837 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.8825 0.513 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.5015 -0.121 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.1525 0.893 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.2315 0.383 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.1295 -0.383 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.9885 0.855 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.9435 0.435 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [0.5685 0.623 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.4075 0.747 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.0685 0.815 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.1775 0.717 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.8495 -0.527 ] 最近的种子点是 [ 0.95516895 -0.53949789]，索引（标签）为 10
# 点 [ 0.4605 -0.055 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.7235 0.979 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.9765 0.025 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.9625 0.075 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.9865 -0.033 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.4835 0.737 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.9065 0.345 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.3015 -0.607 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.5365 -0.175 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.8335 -0.629 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [ 0.0085 -0.641 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.6265 0.675 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.5425 -0.333 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.3315 -0.065 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [ 0.2145 -0.777 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.7125 -0.351 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.3345 -0.675 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.5995 0.087 ] 最近的种子点是 [0.58726579 0.11543257]，索引（标签）为 42
# 点 [0.2815 0.601 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [ 0.3725 -0.045 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [ 0.1565 -0.031 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.0765 -0.899 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.4545 0.771 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.1265 -0.925 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9545 0.695 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.5385 0.733 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.2995 -0.305 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [0.8695 0.933 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.9035 0.931 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [0.6615 0.417 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.9445 0.011 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.6655 0.789 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.2255 -0.387 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.2175 -0.863 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.5535 0.399 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.9925 -0.599 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.5735 0.543 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.2325 0.797 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.0215 -0.959 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.9045 -0.365 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [0.0445 0.351 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.8135 -0.301 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [0.0045 0.341 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.0415 -0.349 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.0645 0.315 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.7395 -0.173 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.6855 -0.009 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.9475 -0.595 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.5485 0.281 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [0.5725 0.731 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.3205 -0.377 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [0.2825 0.533 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.1085 -0.743 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.3995 -0.937 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.9755 0.643 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.8005 0.527 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.6355 0.999 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.3195 0.487 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.0125 0.099 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.7835 0.377 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.1285 0.119 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.7595 0.677 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.5765 -0.499 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.8315 -0.049 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.0225 -0.511 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9855 0.229 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.9695 -0.113 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [ 0.6955 -0.363 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.9685 0.529 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.3735 -0.533 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.1755 -0.005 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.4925 0.557 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.2075 0.919 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.6095 0.193 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [0.3105 0.715 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.1215 -0.795 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.7025 0.091 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.8805 -0.059 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.7745 -0.355 ] 最近的种子点是 [ 0.89367688 -0.30185407]，索引（标签）为 36
# 点 [ 0.0705 -0.739 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.5455 0.145 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [0.4475 0.311 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.1605 -0.557 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.0775 0.767 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.3445 0.775 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.2065 -0.319 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.0075 0.297 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.7265 0.371 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.8835 -0.567 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.5615 0.415 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.7275 0.245 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.0855 -0.223 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.1385 -0.185 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [0.9265 0.647 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.8575 0.425 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [0.2975 0.519 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.7115 -0.969 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.0805 -0.561 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.8975 0.055 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.6015 0.429 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.7525 -0.169 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.7145 -0.651 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.2985 0.997 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.6325 -0.137 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.0535 0.397 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.1725 -0.973 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.9985 -0.171 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [0.9555 0.867 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [0.8905 0.273 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.7195 -0.681 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.9775 -0.145 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [0.2085 0.693 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.6495 -0.585 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [ 0.2775 -0.353 ] 最近的种子点是 [ 0.35624278 -0.42002001]，索引（标签）为 3
# 点 [ 0.0235 -0.291 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.0155 0.333 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.8255 0.701 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [0.5775 0.905 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.5075 0.505 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.5745 -0.239 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [0.8245 0.679 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [ 0.9705 -0.191 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [0.4385 0.151 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.7865 0.787 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [0.0285 0.287 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.8215 -0.077 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.6375 -0.941 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [0.3275 0.993 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.7515 -0.587 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.7735 0.093 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.2375 -0.723 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.8655 -0.621 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.6685 0.907 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [ 0.1165 -0.785 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.2455 -0.513 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.5025 -0.425 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.4935 -0.695 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.6235 0.617 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.3065 0.901 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.9815 0.947 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [0.9385 0.271 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.9715 0.889 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [0.7165 0.373 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.4085 -0.667 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.3755 0.843 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.4135 0.827 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.3035 -0.457 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.5395 0.791 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.0455 0.581 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.2265 0.495 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.4515 -0.017 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.6315 -0.989 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.1535 -0.283 ] 最近的种子点是 [ 0.18678509 -0.14422532]，索引（标签）为 30
# 点 [ 0.7175 -0.943 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.2755 -0.791 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.8865 0.249 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [ 0.2675 -0.091 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [0.6725 0.405 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [0.1625 0.565 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.5875 -0.923 ] 最近的种子点是 [ 0.6748304  -0.92046902]，索引（标签）为 37
# 点 [ 0.0625 -0.341 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [ 0.7475 -0.057 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.0265 0.147 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.8505 0.649 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [0.1865 0.859 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.3075 0.707 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [ 0.3705 -0.685 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.2635 0.109 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.4715 0.473 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.5925 0.903 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.4905 0.663 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [ 0.7935 -0.897 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [ 0.3865 -0.643 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.3925 -0.747 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.3565 -0.573 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [ 0.5375 -0.703 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.4275 0.587 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.1585 0.861 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [0.6815 0.073 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.9585 -0.875 ] 最近的种子点是 [ 0.97314729 -0.9994783 ]，索引（标签）为 35
# 点 [0.2515 0.247 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.1685 0.437 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.4435 0.205 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.8635 -0.751 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.2155 -0.815 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.0935 -0.509 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.8295 0.839 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [0.8935 0.045 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.5345 0.293 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [0.0925 0.899 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.6485 -0.187 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.2295 -0.477 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.7045 0.549 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.9335 -0.733 ] 最近的种子点是 [ 0.94277527 -0.58304809]，索引（标签）为 18
# 点 [0.7485 0.801 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [0.6115 0.605 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.4525 0.613 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.5165 0.177 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [ 0.8995 -0.393 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [ 0.6105 -0.227 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.5285 -0.281 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.5895 -0.859 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [ 0.7975 -0.003 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.4895 0.637 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [ 0.9105 -0.443 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [0.4285 0.445 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.9615 0.185 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.1395 0.591 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.2355 0.639 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.9465 0.847 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [ 0.2095 -0.637 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.6215 0.451 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.4205 -0.073 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [0.8885 0.155 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.5255 0.757 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.0745 0.081 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.6945 0.163 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.1905 0.645 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.3675 0.217 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [0.7965 0.175 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [0.6805 0.987 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [ 0.4315 -0.147 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.4555 -0.701 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.9725 0.667 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.9785 0.535 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.6735 -0.601 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.1655 0.891 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.9345 -0.927 ] 最近的种子点是 [ 0.97314729 -0.9994783 ]，索引（标签）为 35
# 点 [0.4355 0.159 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.6895 -0.505 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.9795 0.381 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [0.2545 0.777 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.1095 -0.371 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [ 0.3155 -0.493 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.9935 0.563 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [0.5835 0.409 ] 最近的种子点是 [0.57503061 0.52400905]，索引（标签）为 31
# 点 [ 0.6925 -0.135 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [0.5035 0.869 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.2595 -0.687 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.0355 -0.981 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.8745 0.989 ] 最近的种子点是 [0.90668861 0.97435413]，索引（标签）为 9
# 点 [0.5155 0.207 ] 最近的种子点是 [0.5662756  0.15426978]，索引（标签）为 21
# 点 [ 0.6865 -0.589 ] 最近的种子点是 [ 0.61592881 -0.52988114]，索引（标签）为 27
# 点 [0.5965 0.585 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [0.6845 0.165 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.8795 -0.435 ] 最近的种子点是 [ 0.91730766 -0.36469626]，索引（标签）为 28
# 点 [ 0.9375 -0.255 ] 最近的种子点是 [ 0.97093271 -0.28576481]，索引（标签）为 24
# 点 [ 0.2465 -0.789 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.0545 0.483 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.5185 -0.855 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [ 0.3095 -0.079 ] 最近的种子点是 [ 0.27394089 -0.00693449]，索引（标签）为 32
# 点 [0.3485 0.917 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.8035 -0.649 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.9175 -0.463 ] 最近的种子点是 [ 0.95516895 -0.53949789]，索引（标签）为 10
# 点 [ 0.9945 -0.043 ] 最近的种子点是 [0.77684821 0.00907629]，索引（标签）为 41
# 点 [ 0.7435 -0.699 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.5825 0.083 ] 最近的种子点是 [0.58726579 0.11543257]，索引（标签）为 42
# 点 [0.3575 0.455 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.4495 -0.983 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.5405 0.885 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [0.1665 0.461 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.6435 0.953 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.1945 -0.867 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9875 0.545 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.0815 -0.755 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.9995 0.347 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [0.1125 0.411 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.3185 0.577 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.4505 0.183 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [ 0.4365 -0.249 ] 最近的种子点是 [ 0.54332928 -0.2790227 ]，索引（标签）为 19
# 点 [ 0.0405 -0.531 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.7855 0.171 ] 最近的种子点是 [0.64435285 0.11995486]，索引（标签）为 39
# 点 [ 0.0665 -0.767 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.2025 0.115 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.7085 0.525 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.6065 -0.787 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [ 0.1315 -0.023 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.2895 0.829 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [ 0.8595 -0.883 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [ 0.6085 -0.769 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [0.1355 0.465 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.4005 0.475 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.1835 0.033 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [ 0.1735 -0.689 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [0.2965 0.723 ] 最近的种子点是 [0.40022392 0.74348447]，索引（标签）为 23
# 点 [0.2705 0.595 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.2885 0.283 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.4595 -0.647 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.1365 0.681 ] 最近的种子点是 [0.32335712 0.84142614]，索引（标签）为 26
# 点 [0.7345 0.983 ] 最近的种子点是 [0.84129894 0.96838637]，索引（标签）为 38
# 点 [ 0.9955 -0.369 ] 最近的种子点是 [ 0.94382906 -0.34813884]，索引（标签）为 15
# 点 [0.5715 0.755 ] 最近的种子点是 [0.61089477 0.61131753]，索引（标签）为 8
# 点 [ 0.3325 -0.881 ] 最近的种子点是 [ 0.46730774 -0.79506227]，索引（标签）为 6
# 点 [0.7785 0.253 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.4175 0.489 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [ 0.4445 -0.455 ] 最近的种子点是 [ 0.38894107 -0.51077077]，索引（标签）为 20
# 点 [0.7545 0.501 ] 最近的种子点是 [0.88354249 0.56708097]，索引（标签）为 5
# 点 [ 0.8095 -0.987 ] 最近的种子点是 [ 0.81146864 -0.99016983]，索引（标签）为 13
# 点 [ 0.6225 -0.891 ] 最近的种子点是 [ 0.67053276 -0.8878207 ]，索引（标签）为 14
# 点 [ 0.0175 -0.041 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.9595 0.785 ] 最近的种子点是 [0.98120338 0.73840107]，索引（标签）为 7
# 点 [0.1505 0.005 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.3045 0.251 ] 最近的种子点是 [0.31300679 0.16353886]，索引（标签）为 43
# 点 [ 0.9305 -0.833 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [0.9525 0.231 ] 最近的种子点是 [0.95059738 0.24161862]，索引（标签）为 0
# 点 [0.0975 0.129 ] 最近的种子点是 [0.18280204 0.07224477]，索引（标签）为 17
# 点 [0.4665 0.299 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [ 0.1715 -0.535 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.1595 0.923 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.7645 -0.857 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.6645 -0.759 ] 最近的种子点是 [ 0.78566381 -0.78711413]，索引（标签）为 4
# 点 [ 0.2135 -0.449 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.1885 0.561 ] 最近的种子点是 [0.41760764 0.48538619]，索引（标签）为 2
# 点 [0.4565 0.069 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.4165 0.047 ] 最近的种子点是 [0.47855176 0.08406659]，索引（标签）为 22
# 点 [0.1825 0.959 ] 最近的种子点是 [0.10995127 0.99860775]，索引（标签）为 40
# 点 [ 0.1415 -0.803 ] 最近的种子点是 [ 0.2413161 -0.6820683]，索引（标签）为 12
# 点 [ 0.1045 -0.471 ] 最近的种子点是 [ 0.30546052 -0.47357603]，索引（标签）为 34
# 点 [0.1805 0.515 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33
# 点 [0.4375 0.641 ] 最近的种子点是 [0.44968092 0.60645848]，索引（标签）为 16
# 点 [0.7715 0.825 ] 最近的种子点是 [0.80051561 0.69960167]，索引（标签）为 1
# 点 [0.8465 0.391 ] 最近的种子点是 [0.99518578 0.42658318]，索引（标签）为 29
# 点 [0.6135 0.925 ] 最近的种子点是 [0.46087548 0.93457543]，索引（标签）为 11
# 点 [ 0.0375 -0.085 ] 最近的种子点是 [ 0.01337043 -0.16777103]，索引（标签）为 25
# 点 [0.0515 0.571 ] 最近的种子点是 [0.36818905 0.37872631]，索引（标签）为 33

# %%
#获得具体某一个数据点最近的种子

dis, index = tree.query(X_f_swapped[5]) #返回目标点最近的种子在seed数组中的距离和索引（即该点所在的单元索引）

nearest_seed = seed[index] #返回目标点最近的种子点坐标

print(index) #打印索引，即该点所在的单元索引
print(nearest_seed) #打印最近的种子点坐标
print(X_f_swapped[5]) #打印该点坐标
# Out:
# 6
# [ 0.46730774 -0.79506227]
# [ 0.3285 -0.829 ]

# %%
voronoiData=Voronoi(seed) #使用Voronoi函数进行Voronoi划分，得到Voronoi图的数据
#Voronoi函数的输入是一个点集(二维的话为(n,2)形状)，输出是一个Voronoi对象，包含了Voronoi图的所有信息，包括顶点、边和单元等
vertexAll=voronoiData.vertices #从数据中提取所有Voronoi顶点
cellAll=voronoiData.regions #从数据中提取所有Voronoi单元，一些单元可能为空

#绘制Voronoi图和PPP
#使用内嵌函数绘制Voronoi图，其中show_points和show_vertices参数控制是否显示生成点（即seed/Voronoi的输入点/数据）和顶点（Voronoi各个单元的交点）
voronoi_plot_2d(voronoiData, show_points=True,show_vertices=False)

# plt.scatter(xx, yy, edgecolor='b', facecolor='r') #绘制泊松点的散点图，设置三点的边缘颜色为蓝色，填充颜色为红


#给每个点添加编号
for ii in range(numbPoints):
    plt.text(xx[ii]+xDelta/50, yy[ii]+yDelta/50, ii) #在图标的某个位置上添加文本，文本内容为点的编号，位置为点的坐标加上区域宽度和高度的1/50（为了做微调）

# %%
data = scipy.io.loadmat('../../data/burgers_shock.mat')
#从data字典中取出变量tt和x的值，并转换为一维数组（flatten方法），最后tongg[:,None]将一维数组转换为二维数组
t = data['t'].flatten()[:,None]
x = data['x'].flatten()[:,None]
Exact = np.real(data['usol']).T #从data数据中取出usol的值，并取实部，最后转置，赋值给Exact
#生成一个二位网络，X和T是输出的二维数组
#这个点结果是X和T均为形状为[len(t),len(x)]的二维数组，X的每一行都是x，一共len(t)行，T的每一列都是t，一共len(x)列
X, T = np.meshgrid(x,t)

X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))  #按列堆叠数组，X_star是一个二维数组，其中第一列是X的展平，第二列是T的展平
u_star = Exact.flatten()[:,None]    #对Exact_u使用flatten方法将其转换为一维数组，最后使用[:,None]将其转换为二维数组   


#使用griddata函数将X_star、u_pred插值到网格上，得到U_pred
U_star = griddata(X_star, u_star.flatten(), (X, T), method='cubic')


###### Row 0: u(t,x) ##################    

fig = plt.figure(figsize=(12, 9)) #这里figure是一个figure对象，是一个图形窗口，代表整个图形，设置图形大小为宽9英寸高5 英寸
ax = fig.add_subplot(111) #在图形的1*1网格的第一个位置添加一个子图

#绘图的数据来源
h = ax.imshow(U_star.T, interpolation='nearest', cmap='rainbow', 
              extent=[t.min(), t.max(), x.min(), x.max()], 
              origin='lower', aspect='auto')   #imshow函数用于显示图像，接受一些参数，第一个参数是图像数据，这里是U_pred的转置；第二个参数是插值方法（用于在像素之间插入新的像素），这里是最邻近插值；
                                                   #第三个参数是颜色映射，这里是用彩虹色图；第四个参数是图像的范围；第五个参数是图像的原点位置，这里表示原点在右下角；第六个参数是图像的纵横比，这里表示调整横纵比以填充整个axes对象
                                                   #最后的结果返回一个axesimage对象，也就是h，可以通过这个对象进一步设置图像的属性


#添加颜色条
divider = make_axes_locatable(ax)  #使用 make_axes_locatable 函数创建了一个 AxesDivider 对象。这个函数接受一个 Axes 对象作为参数，返回一个 AxesDivider 对象。AxesDivider 对象可以用来管理子图的布局，特别是当你需要在一个图的旁边添加另一个图时。
cax = divider.append_axes("right", size="5%", pad=0.10) #使用append_axes方法在原始轴的右侧添加了一个新的轴。append_axes 方法接受三个参数：位置（"right"）、大小（"5%"）和间距（0.10）。在原始轴的右侧添加了一个新的轴，新轴的大小是原始轴的 5%，新轴与原始轴之间的间距是 0.05 英寸
   
cbar = fig.colorbar(h, cax=cax)#使用colorbar方法在新轴上添加了一个颜色条。colorbar 方法接受两个参数：axesimage 对象（h）和新轴（cax）。并记这个颜色条的名字是cbar
cbar.ax.tick_params(labelsize=15) #设置颜色条刻度标签大小，这里bar是之前定义的


#在图上绘制散点图
ax.plot(
    X_f_train[:,1], 
    X_f_train[:,0], 
    'kx', label = 'Data (%d points)' % (X_f_train.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
) #在ax上绘制散点图，前两个参数是散点的x坐标和y坐标；kx表示黑色的x（散点形状是x），label是散点的标签，clip_on表示散点可以绘制在轴的边界外
  #新加了一个alpha=1.0用来设置标记的透明度，1.0表示完全不透明  


voronoi_plot_2d(voronoiData, ax=ax, show_points=True, show_vertices=False, line_colors='k', line_width=0.5)

#设置图的标签、图例、标题和刻度标签
#设置ax子图的x轴的标签为t，y轴的标签为x。这里$t$和$x$是latex格式的文本，用于生成数学公式
ax.set_xlabel('$t$', size=20)
ax.set_ylabel('$x$', size=20)
#设置子图ax的图例，第一个参数用来设置图例的位置，这里表示图例放在上方中央;第二个参数用来设置图例的锚点，接受一个元组，表示x和y坐标，表示把图例的锚点设置在x坐标为0.9，y坐标为-0.05处;frameon=False表示不显示图例的边框;第三个参数设置图例的列数，分为5列；最后一个参数设置图例属性，接受字典，这里表示设置图例字体大小为15；最后返回的leg是一个legend对象，表示图形的图例
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.9, -0.05), 
    ncol=5, 
    frameon=False, 
    prop={'size': 15}
)
#设置子图ax的标题为$u(t,x)$，表示latex格式的文本，用于生成数学公式，fontsize=10表示字体大小为20
ax.set_title('$u(t,x)$', fontsize = 20) # font size doubled，两倍化子图标题
ax.tick_params(labelsize=15)#用来设置刻度标签的大小。`tick_params`是`Axes`对象的一个方法，可以用来设置刻度线的属性。在这里，`labelsize=15` 是用来设置刻度标签的字体大小的。


#给每个点添加编号
for ii in range(numbPoints):
    ax.text(xx[ii], yy[ii], ii) #在图标的某个位置上添加文本，文本内容为点的编号，位置为点的坐标加上区域宽度和高度的1/50（为了做微调）
    
#在图上绘制第五个点的情况
ax.plot(
    X_f_train[5,1], 
    X_f_train[5,0], 
    'ro',  
    markersize = 8,  # marker size doubled
    clip_on = False,
    alpha=1.0
) #在ax上绘制散点图，前两个参数是散点的x坐标和y坐标；kx表示黑色的x（散点形状是x），label是散点的标签，clip_on表示散点可以绘制在轴的边界外
  #新加了一个alpha=1.0用来设置标记的透明度，1.0表示完全不透明  

#显示图片
plt.show() #显示所有打开的图形的函数
